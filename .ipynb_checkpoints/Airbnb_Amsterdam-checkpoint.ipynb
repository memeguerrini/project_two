# %% [markdown]
# ### Amsterdam’s Airbnb Market in 2018 - 2019
# Data Analysis Exploration

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
from pandas.io.json import json_normalize
import gmaps
import gmaps.datasets
import folium
from folium.plugins import FastMarkerCluster
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0b4f9ed64d15> in <module>
#       7 import gmaps
#       8 import gmaps.datasets
# ----> 9 import folium
#      10 from folium.plugins import FastMarkerCluster
#      11 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'folium'

# %% [markdown]
# ## Store CSV into DataFrames & Clean

# %% [markdown]
# ### Calendar Data Set (.CSV)

# %%
# Read in the calendar data set
df_calendar = pd.read_csv('./Data/calendar.csv')
df_calendar.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7d0f344d87e9> in <module>
#       1 # Read in the calendar data set
# ----> 2 df_calendar = pd.read_csv('./Data/calendar.csv')
#       3 df_calendar.head()
#
# ...

# %%
df_calendar.count()
# Out:
# listing_id    1048575
# date          1048575
# available     1048575
# price          264455
# dtype: int64

# %%
# Print rows and columns in calendar data set
print("Number of rows and columns: ", df_calendar.shape)
# Assess null values
print(df_calendar.isnull().sum())
# Describe
print(df_calendar.describe(include='all'))
# Out:
# Number of rows and columns:  (1048575, 4)
# listing_id         0
# date               0
# available          0
# price         784120
# dtype: int64
#           listing_id        date available          price
# count   1.048575e+06     1048575   1048575  264455.000000
# unique           NaN         366         2            NaN
# top              NaN  2019-12-05         f            NaN
# freq             NaN        2874    784120            NaN
# mean    2.208400e+06         NaN       NaN     192.518088
# std     1.344701e+06         NaN       NaN     316.496214
# min     2.818000e+03         NaN       NaN      30.000000
# 25%     9.988220e+05         NaN       NaN     105.000000
# 50%     2.059078e+06         NaN       NaN     150.000000
# 75%     3.407526e+06         NaN       NaN     220.000000
# max     4.737169e+06         NaN       NaN    8000.000000

# %%
# Remove missing values
df_calendar.dropna(how='any')
# Out:
#          listing_id        date available  price
# 240          255809  2019-12-05         t  150.0
# 241          255809  2019-12-04         t  150.0
# 242          255809  2019-12-03         t  150.0
# 243          255809  2019-12-02         t  150.0
# 244          255809  2019-12-01         t  150.0
# ...             ...         ...       ...    ...
# 1048501     4435968  2019-04-29         t  114.0
# 1048502     4435968  2019-04-28         t  114.0
# 1048503     4435968  2019-04-27         t  113.0
# 1048504     4435968  2019-04-26         t  113.0
# 1048505     4435968  2019-04-25         t  113.0
#
# [264455 rows x 4 columns]

# %% [markdown]
# ### Listings Data Set (.CSV)

# %%
# Read in the listings data set
df_listings = pd.read_csv('./Data/listings_details.csv')
df_listings.head()
# Out:
# C:\Users\User 1\anaconda\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (87) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       id                         listing_url       scrape_id last_scraped  \
# 0   2818   https://www.airbnb.com/rooms/2818  20181206172549   2018-12-06
# 1   3209   https://www.airbnb.com/rooms/3209  20181206172549   2018-12-06
# 2  20168  https://www.airbnb.com/rooms/20168  20181206172549   2018-12-06
# 3  25428  https://www.airbnb.com/rooms/25428  20181206172549   2018-12-06
# 4  27886  https://www.airbnb.com/rooms/27886  20181206172549   2018-12-06
#
#                                                 name  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1                  Quiet apt near center, great view
# 2         100%Centre-Studio 1 Private Floor/Bathroom
# 3                Lovely apt in City Centre (Jordaan)
# ...

# %%
df_listings.count()
# Out:
# id                                  20030
# listing_url                         20030
# scrape_id                           20030
# last_scraped                        20030
# name                                19992
#                                     ...
# cancellation_policy                 20030
# require_guest_profile_picture       20030
# require_guest_phone_verification    20030
# calculated_host_listings_count      20030
# reviews_per_month                   17624
# Length: 96, dtype: int64

# %%
df_listings.dropna(how='any')
# Out:
# Empty DataFrame
# ...

# %%
# Print rows and columns in calendar data set
print("Number of rows and columns: ", df_listings.shape)
# Assess null values
print(df_listings.isnull().sum())
# Out:
# Number of rows and columns:  (20030, 96)
# id                                     0
# listing_url                            0
# scrape_id                              0
# last_scraped                           0
# name                                  38
#                                     ...
# cancellation_policy                    0
# require_guest_profile_picture          0
# require_guest_phone_verification       0
# calculated_host_listings_count         0
# reviews_per_month                   2406
# Length: 96, dtype: int64

# %% [markdown]
# ### Reviews Data Set (.CSV)

# %%
# Read the reviews data set
df_reviews = pd.read_csv('./Data/reviews_details.csv')
df_reviews.head()
# Out:
#    listing_id    id        date  reviewer_id reviewer_name  \
# 0        2818  1191  2009-03-30        10952           Lam
# 1        2818  1771  2009-04-24        12798         Alice
# 2        2818  1989  2009-05-03        11869       Natalja
# 3        2818  2797  2009-05-18        14064       Enrique
# 4        2818  3151  2009-05-25        17977       Sherwin
#
#                                             comments
# 0  Daniel is really cool. The place was nice and ...
# 1  Daniel is the most amazing host! His place is ...
# 2  We had such a great time in Amsterdam. Daniel ...
# 3  Very professional operation. Room is very clea...
# 4  Daniel is highly recommended.  He provided all...

# %%
df_reviews.count()
# Out:
# listing_id       431830
# id               431830
# date             431830
# reviewer_id      431830
# reviewer_name    431830
# comments         431300
# dtype: int64

# %%
# Print rows and columns in reviews data set
print("Number of rows and columns: ", df_reviews.shape)
# Assess null values
print(df_reviews.isnull().sum())
# Describe
print(df_reviews.describe(include='all'))
# Out:
# Number of rows and columns:  (431830, 6)
# listing_id         0
# id                 0
# date               0
# reviewer_id        0
# reviewer_name      0
# comments         530
# dtype: int64
#           listing_id            id        date   reviewer_id reviewer_name  \
# count   4.318300e+05  4.318300e+05      431830  4.318300e+05        431830
# unique           NaN           NaN        2874           NaN         54244
# top              NaN           NaN  2017-05-28           NaN         David
# freq             NaN           NaN        1429           NaN          2961
# mean    9.540278e+06  1.676551e+08         NaN  5.844055e+07           NaN
# std     7.646134e+06  1.027225e+08         NaN  5.424683e+07           NaN
# min     2.818000e+03  1.191000e+03         NaN  4.370000e+02           NaN
# 25%     2.482541e+06  7.596344e+07         NaN  1.533860e+07           NaN
# 50%     7.815853e+06  1.591030e+08         NaN  3.931767e+07           NaN
# ...

# %%
df_reviews.dropna(how='any')
# Out:
#         listing_id         id        date  reviewer_id  reviewer_name  \
# 0             2818       1191  2009-03-30        10952            Lam
# 1             2818       1771  2009-04-24        12798          Alice
# 2             2818       1989  2009-05-03        11869        Natalja
# 3             2818       2797  2009-05-18        14064        Enrique
# 4             2818       3151  2009-05-25        17977        Sherwin
# ...            ...        ...         ...          ...            ...
# 431825    30435529  355474875  2018-12-04    131376847           Andy
# 431826    30439111  355041813  2018-12-02    103201416       Mohammed
# 431827    30518120  355519016  2018-12-04    228738702       Valeriya
# 431828    30525429  355658538  2018-12-05    111439550          Lucas
# 431829    30550093  355872191  2018-12-06    226911176  Mohamed Amine
#
#                                                  comments
# 0       Daniel is really cool. The place was nice and ...
# ...

# %%
#Remove last column
df_reviews = df_reviews.drop(columns = df_reviews.columns[-1])
df_reviews.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\USER1~1\AppData\Local\Temp/ipykernel_35028/531247596.py in <module>
#       1 #Remove last column
# ----> 2 df_reviews = df_reviews.drop(columns = df_reviews.comments[-1])
#       3 df_reviews.head()
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %% [markdown]
# ### Neighborhoods Data set (.geojson)

# %%
neighborhoods_df = gpd.read_file("./Data/neighbourhoods.geojson")
neighborhoods_df.head()
# Out:
#               neighbourhood neighbourhood_group  \
# 0              Bijlmer-Oost                None
# 1                Noord-Oost                None
# 2                Noord-West                None
# 3                 Oud-Noord                None
# 4  IJburg - Zeeburgereiland                None
#
#                                             geometry
# 0  MULTIPOLYGON Z (((4.99167 52.32444 43.06929, 4...
# 1  MULTIPOLYGON Z (((5.07916 52.38865 42.95663, 5...
# 2  MULTIPOLYGON Z (((4.93072 52.41161 42.91539, 4...
# 3  MULTIPOLYGON Z (((4.95242 52.38983 42.95411, 4...
# 4  MULTIPOLYGON Z (((5.03906 52.35458 43.01664, 5...

# %%
# Print rows and columns in calendar data set
print("Number of rows and columns: ", neighborhoods_df.shape)
# Assess null values
print(neighborhoods_df.isnull().sum())
# Describe
print(neighborhoods_df.describe(include='all'))
# Out:
# Number of rows and columns:  (22, 3)
# neighbourhood           0
# neighbourhood_group    22
# geometry                0
# dtype: int64
#        neighbourhood neighbourhood_group  \
# count             22                   0
# unique            22                   0
# top     Bijlmer-Oost                 NaN
# freq               1                 NaN
#
#                                                  geometry
# count                                                  22
# unique                                                 22
# top     (POLYGON Z ((4.991669 52.324436 43.069286, 4.9...
# freq                                                    1

# %% [markdown]
# # Analysis of Questions

# %% [markdown]
# #### Property types

# %%
# Exploration Categorical Feature - property_type
prop_vals = df_listings['property_type'].value_counts()
(prop_vals/df_listings.shape[0]).plot(kind="bar",figsize=(8,5),fontsize=12);
plt.title("Property Type",fontsize=15);

#Print
plt.savefig("./Images/Av_propertyT_Fig.03.png", bbox_inches = "tight")

# %% [markdown]
# #### Accommodations per person

# %%
# Accommodation according to listings
feq=df_listings['accommodates'].value_counts().sort_index()
feq.plot.bar(figsize=(8,5), color='b', width=1, rot=0)
plt.title("Accommodates (number of people)", fontsize=15)
plt.ylabel('Number of listings', fontsize=8)
plt.xlabel('Accommodates', fontsize=8)

#Print
plt.savefig("./Images/Acomodation_Fig.04.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# #### Average price by month

# %%
# Plot the average price by month 
df_calendar['year'] = pd.DatetimeIndex(df_calendar['date']).year
df_calendar['month'] = pd.DatetimeIndex(df_calendar['date']).month

# In order to average price, we will be converting it to float and removing the $ sign
df_calendar['price'] = df_calendar['price'].replace('[\$,]', '', regex=True).astype(float)

df_calendar.groupby(['year','month'])[['price']].mean().plot(kind="bar",figsize=(8,5),fontsize=10);

#Print
plt.savefig("./Images/Av_priceMth_Fig.02.png", bbox_inches = "tight")

# %% [markdown]
# #### Average price by Neighborhood

# %%
# Plot the average price by neighborhood

# In order to average price, we will be converting it to float and removing the $ sign
df_listings['price'] = df_listings['price'].replace('[\$,]', '', regex=True).astype(float)

print(df_listings.groupby(['neighbourhood_cleansed'])[['price']].mean().sort_values(by='price',ascending=False))
df_listings.groupby(['neighbourhood_cleansed'])[['price']].mean().plot(figsize=(8,5), fontsize=10);

#Print
plt.savefig("./Images/Av_priceNbh_Fig.01.png", bbox_inches = "tight")
plt.tight_layout()
# Out:
#                                              price
# neighbourhood_cleansed
# Centrum-West                            189.920034
# Centrum-Oost                            189.376301
# Zuid                                    171.126995
# IJburg - Zeeburgereiland                165.157080
# Oud-Noord                               157.684764
# De Pijp - Rivierenbuurt                 157.178500
# Buitenveldert - Zuidas                  153.087786
# De Baarsjes - Oud-West                  143.849218
# Oud-Oost                                143.398596
# Westerpark                              141.004027
# Watergraafsmeer                         137.514493
# Oostelijk Havengebied - Indische Buurt  126.089677
# Geuzenveld - Slotermeer                 125.735849
# De Aker - Nieuw Sloten                  124.711268
# Noord-West                              120.171875
# Noord-Oost                              118.638132
# Bos en Lommer                           116.996507
# ...

# %% [markdown]
# #### Top 10 Best Neighborhoods

# %%
# Plot top 10 neighborhoods
top10_neigh = df_listings.groupby(['neighbourhood'])[['price']].mean().sort_values(by='price',ascending=False).head()
top10_neigh.plot(kind='bar',figsize=(8,5),fontsize=13);

# Print
plt.savefig("./Images/Best_Neighb_Fig.05.png", bbox_inches = "tight")

# %% [markdown]
# #### Top 10 bottom neighborhoods

# %%
# Plot bottom 10 neighborhoods
bottom10_neigh = df_listings.groupby(['neighbourhood_cleansed'])[['price']].mean().sort_values(by='price',ascending=False).tail()
bottom10_neigh.plot(kind='bar',figsize=(8,5),fontsize=13);

# Print
plt.savefig("./Images/Bottom_Neighb_Fig.06.png", bbox_inches = "tight")

# %% [markdown]
# #### Types of Rooms

# %%
# Room types
freq = df_listings['room_type']. value_counts().sort_values(ascending=True)
freq.plot.barh(figsize=(13, 3),fontsize=13, width=1, color = ["g","b","r"])

# Print
plt.savefig("./Images/TypesRoom_Fig.07.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# #### Reviews Analysis

# %%
# Reviews Information
#ax1.tick_params(axis = 'both', labelsize = 16)

listings10 = df_listings[df_listings['number_of_reviews']>=10]

fig = plt.figure(figsize=(20,15))
plt.rc('xtick', labelsize=16) 
plt.rc('ytick', labelsize=16)

ax1 = fig.add_subplot(321)
feq=listings10['review_scores_location'].value_counts().sort_index()
ax1=feq.plot.bar(color='b', width=1, rot=0)


plt.title("Location", fontsize=24)
plt.ylabel('Number of listings', fontsize=14)
plt.xlabel('Average review score', fontsize=14)

ax2 = fig.add_subplot(322)
feq=listings10['review_scores_cleanliness'].value_counts().sort_index()
ax2=feq.plot.bar(color='b', width=1, rot=0)
plt.title("Cleanliness", fontsize=24)
plt.ylabel('Number of listings', fontsize=14)
plt.xlabel('Average review score', fontsize=14)

ax3 = fig.add_subplot(323)
feq=listings10['review_scores_value'].value_counts().sort_index()
ax3=feq.plot.bar(color='b', width=1, rot=0)
plt.title("Value", fontsize=24)
plt.ylabel('Number of listings', fontsize=14)
plt.xlabel('Average review score', fontsize=14)

ax4 = fig.add_subplot(324)
feq=listings10['review_scores_communication'].value_counts().sort_index()
ax4=feq.plot.bar(color='b', width=1, rot=0)
plt.title("Communication", fontsize=24)
plt.ylabel('Number of listings', fontsize=14)
plt.xlabel('Average review score', fontsize=14)

ax5 = fig.add_subplot(325)
feq=listings10['review_scores_checkin'].value_counts().sort_index()
ax5=feq.plot.bar(color='b', width=1, rot=0)
plt.title("Arrival", fontsize=24)
plt.ylabel('Number of listings', fontsize=14)
plt.xlabel('Average review score', fontsize=14)

ax6 = fig.add_subplot(326)
feq=listings10['review_scores_accuracy'].value_counts().sort_index()
ax6=feq.plot.bar(color='b', width=1, rot=0)
plt.title("Accuracy", fontsize=24)
plt.ylabel('Number of listings', fontsize=14)
plt.xlabel('Average review score', fontsize=14)

# Print
plt.savefig("./Images/ReviewsInfo_Fig.08.png", bbox_inches = "tight")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Neighborhoods

# %%
neighborhoods_df.head()
# Out:
#               neighbourhood neighbourhood_group  \
# 0              Bijlmer-Oost                None
# 1                Noord-Oost                None
# 2                Noord-West                None
# 3                 Oud-Noord                None
# 4  IJburg - Zeeburgereiland                None
#
#                                             geometry
# 0  MULTIPOLYGON Z (((4.99167 52.32444 43.06929, 4...
# 1  MULTIPOLYGON Z (((5.07916 52.38865 42.95663, 5...
# 2  MULTIPOLYGON Z (((4.93072 52.41161 42.91539, 4...
# 3  MULTIPOLYGON Z (((4.95242 52.38983 42.95411, 4...
# 4  MULTIPOLYGON Z (((5.03906 52.35458 43.01664, 5...

# %%
print(neighborhoods_df.describe(include='all'))
# Out:
#        neighbourhood neighbourhood_group  \
# count             22                   0
# unique            22                   0
# top     Bijlmer-Oost                 NaN
# freq               1                 NaN
#
#                                                  geometry
# count                                                  22
# unique                                                 22
# top     (POLYGON Z ((4.991669 52.324436 43.069286, 4.9...
# freq                                                    1

# %% [markdown]
# #### Listings per Zone

# %%
# Show listings in a map x zone
lats2018 = df_listings['latitude'].tolist()
lons2018 = df_listings['longitude'].tolist()
locations = list(zip(lats2018, lons2018))

map1 = folium.Map(location=[52.3244, 4.9916], zoom_start=11.5)
FastMarkerCluster(data=locations).add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
